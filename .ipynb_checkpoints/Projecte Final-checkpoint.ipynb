# %% [markdown]
# # Projecte final

# %% [markdown]
# ## Conjunt de dades escollit

# %% [markdown]
# El siguiente conjunto de datos se ha extraido de la web del ayuntamiento de Barrcelona https://opendata-ajuntament.barcelona.cat/es
#
# ## Ficheros descargados:

# %% [markdown]
# ### 1) Nuevo fichero General de Entidades Ciudadanas de la ciudad de Barcelona (12/04/2023)
# El Fichero General de Entidades Ciudadanas es uno de los instrumentos de relación del Ayuntamiento de Barcelona con las entidades y grupos de hecho de la ciudad. Su creación está prevista en las Normas reguladoras de la participación ciudadana (artículo 9) y está reglamentado mediante las Normas reguladoras del Fichero general de entidades ciudadanas (BOP 26/2/2004).
#
# - Gerencia: Gerència de Drets de Ciutadania, Participació i Transparència
# - Departamento: Departament d'Associacionisme i Iniciatives Ciutadanes
# - Fuente: Comissionat de Participació Ciutadana i Associacionisme
# - Agenda 2030. ODS Principal: ODS 16: Paz, justícia e instituciones sólidas
# - Agenda 2030. ODS Colateral 1: ODS 17: Alianza para lograr los objetivos
# - Frecuencia actualización: Mensual
# - Información histórica: Sí

# %% [markdown]
# #### Explicación de las variables del fichero:
#
# 01.**Tipologia_E_GF**: Tipologia de l'entitat. Indica si es tracta d'una entitat o grup de fet. Totes les entitats tenen aquest camp amb el valor "E"
# 02.**Nif**: NIF de l'entitat
# 03.**Total_Voluntaris**: Nombre de voluntaris que participen a les activitats de l'entitat
# 04.**Total_Professionals**: Nombre total de professionals que treballen a l'entitat
# 05.**Tipus_Activitat**: Indica si l'activitat és de tipus "permanent" o "temporal"
# 06.**Forma_Juridica**: Indica la forma jurídica amb la qual s'ha constituït l'entitat
# 07.**Codi_E_GF**: Codi identificador de l'entitat
# 08.**Nom_E_GF**: Nom de l'entitat
# 09.**Nom_Popular**: Nom pel qual es coneix popularment a l'entitat
# 10.**Sigla**: Sigla corresponent a l'entitat
# 11.**Nom_Poblacio**: Nom de la població on es troba l'entitat
# 12.**Codi_Districte**: Codi de districte seguint la codificació de l'Ajuntament de Barcelona
# 13.**Nom_Districte**: Nom del districte
# 14.**Codi_Barri**: Codi del barri
# 15.**Nom_Barri**: Nom del barri
# 16.**Url_Preferent**: URL preferent
# 17.**Any_Constitucio**: Any de constitució de l'entitat
# 18.**Sector_Territorial**: Territori en el qual l'entitat desenvolupa les seves activitats
# 19.**Total_Socis**: Nombre total de socis de l'entitat
# 20.**Telefon_Preferent**: Telèfon preferent de contacte
# 21.**Correu_Preferent**: Adreça preferent de correu electrònic
# 22.**Sector_Tematic_1**: Primer sector temàtic
# 23.**Sector_Tematic_2**: Segon sector temàtic
# 24.**Sector_Tematic_3**: Tercer sector temàtic
# 25.**XXSS_Instagram**: Instagram
# 26.**XXSS_Twitter**: Twitter
# 27.**XXSS_Facebook**: Facebook
# 28.**XXSS_Altres**: Altres xarxes socials
# 29.**Codi_tipus_via**: Codi tipus via codificat AjBCN
# 30.**Tipus_Via**: Tipus via
# 31.**Codi_Carrer**: Codi carrer codificació AjBCN
# 32.**Nom_Carrer**: Nom del carrer
# 33.**Codi_número_carrer**: Codi número carrer codificació AjBCN
# 34.**Numero_Carrer**: Número
# 35.**Escala**: Escala
# 36.**Pis**: Pis
# 37.**Porta**: Porta
# 38.**Latitud**: Latitud
# 39.**Longitud**: Longitud
# 40.**X_ETRS89**: Coordenada X en ETRS89
# 41.**Y_ETRS89**: Coordenada Y en ETRS89

# %% [markdown]
# ### 2) Subvenciones concedidas a entitades de la ciudad de Barcelona (12/04/2023)
# Este conjunto de datos incluye las subvenciones otorgadas a las diferentes entidades inscritas en el Fichero General de Entidades de la ciudad de Barcelona, incluyendo el título del proyecto e importe de la subvención.
#
# - Gerencia: Gerència de Drets de Ciutadania, Participació i Transparència
# - Departamento: Departament d'Associacionisme i Iniciatives Ciutadanes
# - Fuente: Ajuntament de Barcelona
# - Agenda 2030. ODS Principal: ODS 16: Paz, justícia e instituciones sólidas
# - Agenda 2030. ODS Colateral 1: ODS 17: Alianza para lograr los objetivos
# - Frecuencia actualización: Anual
# - Información histórica: No

# %% [markdown]
# #### Explicación de las variables del fichero:
#
# 01.**Tipologia_E_GF**: Tipologia de l'entitat.Indica si es tracta d'una entitat o grup de fet. Totes les entitats tenen aquest camp amb el valor "E"
# 02.**Codi_E_GF**: Codi intern de l'entitat. Consultar Nou fitxer General d'Entitats Ciutadanes de la ciutat de Barcelona
# 03.**Entitat_Municipal**: Entitat que atorga la subvenció
# 04.**Organ_Gestor**: Òrgan gestor de la subvenció
# 05.**Any**: Any de convocatòria de la subvenció
# 06.**Tipologia_De_Subvencio**: Tipologia de la subvenció
# 07.**Objecte**: Títol del projecte presentat per l'entitat
# 08.**Import_Sollicitat**: Import sol·licitat (€)
# 09.**Import_Total_Projecte**: Import total del projecte presentat (€)
# 10.**Import_Atorgat_Inicial**: Import atorgat inicialment (€)
# 11.**Import_Reintegrat_Total**: Import reintegrat (€)

# %% [markdown]
# **Objetivos:**
# 1) Analizar los datos del fichero general estableciendo la distribución estadística de tipologías de entidades ciudadanas, su distribución por la ciudad, los valores medios de integrantes y socios, el alcance territorial, y el nivel de digitalización.
# 2) Establecer una analisis de correlaciones entre las subvenciones y las características de las entidades identificando marcadores de interes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import iqr

# %% [markdown]
# ## 1) Importación de ficheros, sanity checks y "mergeado" de las bases de datos

# %% [markdown]
# ### a.  Entidades

# %%
df_entidades = pd.read_csv("C:/Users/alpid/Downloads/2023_1S_ENTITIES.csv")
df_entidades.head()
# Out:
#   Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 0              E  G66024894               0.0                  0.0
# 1              E  R0800530H               0.0                  0.0
# 2              E  G08489528               0.0                  0.0
# 3              E  G01675180               0.0                  0.0
# 4              E  F67141648               0.0                  0.0
#
#   Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 0             NaN     Associació  99888005242
# 1             NaN     Associació  99746315497
# 2             NaN       Fundació  99739953046
# 3             NaN     Associació  99674314027
# 4             NaN    Cooperativa  99564110147
#
#                                     Nom_E_GF Nom_Popular Sigla Nom_Poblacio  \
# 0  Associació d'Afectats d'Urticària Crònica         NaN  AAUC    BARCELONA
# 1           Parròquia Sant Ignasi de Loiola          NaN   NaN    BARCELONA
# ...

# %% [markdown]
# **Voy a reemplazar los valores 0.0 por Nan para no tener resutlados erroneos**.

# %%
df_entidades = df_entidades.replace(0.0, np.nan)
df_entidades.head()
# Out:
#   Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 0              E  G66024894               NaN                  NaN
# 1              E  R0800530H               NaN                  NaN
# 2              E  G08489528               NaN                  NaN
# 3              E  G01675180               NaN                  NaN
# 4              E  F67141648               NaN                  NaN
#
#   Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 0             NaN     Associació  99888005242
# 1             NaN     Associació  99746315497
# 2             NaN       Fundació  99739953046
# 3             NaN     Associació  99674314027
# 4             NaN    Cooperativa  99564110147
#
#                                     Nom_E_GF Nom_Popular Sigla Nom_Poblacio  \
# 0  Associació d'Afectats d'Urticària Crònica         NaN  AAUC    BARCELONA
# 1           Parròquia Sant Ignasi de Loiola          NaN   NaN    BARCELONA
# ...

# %%
df_entidades.shape
# Out:
# (5484, 41)

# %% [markdown]
# Hay 5484 entidades identificadas.

# %%
df_entidades.isna().all()
# Out:
# Tipologia_E_GF         False
# Nif                    False
# Total_Voluntaris       False
# Total_Professionals    False
# Tipus_Activitat        False
# Forma_Juridica         False
# Codi_E_GF              False
# Nom_E_GF               False
# Nom_Popular            False
# Sigla                  False
# Nom_Poblacio           False
# Codi_Districte         False
# Nom_Districte          False
# Codi_Barri             False
# Nom_Barri              False
# Url_Preferent          False
# Any_Constitucio        False
# Sector_Territorial     False
# Total_Socis            False
# Telefon_Preferent      False
# Correu_Preferent       False
# Sector_Tematic_1       False
# Sector_Tematic_2       False
# Sector_Tematic_3       False
# XXSS_Instagram         False
# XXSS_Twitter           False
# XXSS_Facebook          False
# XXSS_Altres            False
# Codi_tipus_via         False
# Tipus_Via              False
# Codi_Carrer            False
# Nom_Carrer             False
# ...

# %% [markdown]
# No hay ninguna columna con sus valores 100% NaN.

# %% [markdown]
# Analicemos la base de datos:

# %%
df_entidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5484 entries, 0 to 5483
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tipologia_E_GF       5484 non-null   object
#  1   Nif                  5481 non-null   object
#  2   Total_Voluntaris     10 non-null     float64
#  3   Total_Professionals  9 non-null      float64
#  4   Tipus_Activitat      3 non-null      object
#  5   Forma_Juridica       5481 non-null   object
#  6   Codi_E_GF            5484 non-null   int64
#  7   Nom_E_GF             5484 non-null   object
#  8   Nom_Popular          11 non-null     object
#  9   Sigla                988 non-null    object
#  10  Nom_Poblacio         5484 non-null   object
#  11  Codi_Districte       5484 non-null   int64
#  12  Nom_Districte        5484 non-null   object
#  13  Codi_Barri           5484 non-null   int64
#  14  Nom_Barri            5484 non-null   object
# ...

# %%
df_entidades.isna().sum()
# Out:
# Tipologia_E_GF            0
# Nif                       3
# Total_Voluntaris       5474
# Total_Professionals    5475
# Tipus_Activitat        5481
# Forma_Juridica            3
# Codi_E_GF                 0
# Nom_E_GF                  0
# Nom_Popular            5473
# Sigla                  4496
# Nom_Poblacio              0
# Codi_Districte            0
# Nom_Districte             0
# Codi_Barri                0
# Nom_Barri                 0
# Url_Preferent          2546
# Any_Constitucio           0
# Sector_Territorial     1510
# Total_Socis            4148
# Telefon_Preferent       790
# Correu_Preferent        603
# Sector_Tematic_1          1
# Sector_Tematic_2       3894
# Sector_Tematic_3       4829
# XXSS_Instagram         5159
# XXSS_Twitter           4708
# XXSS_Facebook          4385
# XXSS_Altres            5193
# Codi_tipus_via            2
# Tipus_Via                 2
# Codi_Carrer               2
# Nom_Carrer                2
# Codi_número_carrer        2
# ...

# %% [markdown]
# ---------------

# %% [markdown]
# - 1 entidad:
#     * no tiene indetificado el Sector temático 1 (se trata de la Parròquia Sant paulí de Nola)

# %%
df_entidad_asin_sector_tematico_1 = df_entidades[df_entidades["Sector_Tematic_1"].isna()]
df_entidad_asin_sector_tematico_1
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 4760              E  R5800131D               NaN                  NaN
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 4760             NaN         Altres  47498410148
#
#                           Nom_E_GF Nom_Popular Sigla Nom_Poblacio  \
# 4760  Parròquia Sant Paulí de Nola         NaN   NaN    BARCELONA
#
#       Codi_Districte Nom_Districte  Codi_Barri              Nom_Barri  \
# 4760              10    Sant Martí          70  el Besòs i el Maresme
#
#      Url_Preferent  Any_Constitucio Sector_Territorial  Total_Socis  \
# 4760           NaN             1600                NaN          NaN
#
#      Telefon_Preferent           Correu_Preferent Sector_Tematic_1  \
# 4760         933143558   santpauli160@arqbcn.org               NaN
#
#      Sector_Tematic_2 Sector_Tematic_3 XXSS_Instagram XXSS_Twitter  \
# 4760              NaN              NaN            NaN          NaN
#
# ...

# %% [markdown]
# La Parroquia Sat Paulí de Nola carece de Sector tematic definido (es la que no tiene definido el Sector_tematic_1, aunque tampoco el 2 y el 3).

# %% [markdown]
# ---------

# %% [markdown]
# - 1 entidad:
#     * tiene nombre de Poblacion fuera de Barcelona: Badía del Vallés (se trata de la Federació Catalana de Judo i Disciplines Assoc.., pero en distrito indican Sant Gervais, asi que asumo que se trata de un error y que está en Barcelona)."

# %%
df_entidades["Nom_Poblacio"].value_counts()
# Out:
# BARCELONA           3868
# Barcelona           1596
# barcelona             19
# BADIA DEL VALLES       1
# Name: Nom_Poblacio, dtype: int64

# %% [markdown]
# Corrijo todas a Barcelona:

# %%
df_entidades['Nom_Poblacio'] = df_entidades['Nom_Poblacio'].str.lower().str.capitalize()

# %%
df_entidades["Nom_Poblacio"].value_counts()
# Out:
# Barcelona           5483
# Badia del valles       1
# Name: Nom_Poblacio, dtype: int64

# %%
df_entidades_fuera_de_Barcelona = df_entidades.loc[df_entidades["Nom_Poblacio"] == "Badia del valles"]
df_entidades_fuera_de_Barcelona
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 4114              E  G08899908               NaN                  NaN
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 4114             NaN     Associació  92086002921
#
#                                                Nom_E_GF Nom_Popular Sigla  \
# 4114  Federació Catalana de Judo i Disciplines Assoc...         NaN   NaN
#
#           Nom_Poblacio  Codi_Districte        Nom_Districte  Codi_Barri  \
# 4114  Badia del valles               5  Sarrià-Sant Gervasi          27
#
#                  Nom_Barri               Url_Preferent  Any_Constitucio  \
# 4114  el Putxet i el Farró  http://www.fedecatjudo.cat             1600
#
#      Sector_Territorial  Total_Socis Telefon_Preferent  \
# 4114          barcelona          NaN         937479757
#
#                Correu_Preferent Sector_Tematic_1        Sector_Tematic_2  \
# 4114  federacio@fedecatjudo.cat       Esportives  Entitats de segon grau
#
# ...

# %% [markdown]
# Observamos que aunque indica que está fuera de barcelona, el distrito indicado es Sarrià-Sant Gervasi, por tanto asumo que se trata de un error

# %% [markdown]
# ------------

# %% [markdown]
# - 2 entidades (Fundación Colegio de Huérfanos de Hacienda y Associació Catalana de Malalties Neuromuscular...) no tienen forma de localizarse físicamente al faltar :
#     * Codigo Tipo de Via,
#     * Tipo de via,
#     * Codigo de Calle,
#     * Nombre de la calle,
#     * Código de número de calle,
#     * Número de calle
#     * Latitud
#     * Longitud
#     * X_ETRS89
#     * Y_ETRS89

# %%
df_entidades_ilocalizables = df_entidades.loc[df_entidades["Codi_tipus_via"].isna()]
df_entidades_ilocalizables
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 1692              E  G83188425               NaN                  NaN
# 5246              E  G63277784               NaN                  NaN
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 1692             NaN     Associació  99400218481
# 5246             NaN     Associació   1270104012
#
#                                                Nom_E_GF Nom_Popular Sigla  \
# 1692         Fundación Colegio de Huérfanos de Hacienda         NaN   NaN
# 5246  Associació Catalana de Malalties Neuromuscular...         NaN   NaN
#
#      Nom_Poblacio  Codi_Districte        Nom_Districte  Codi_Barri  \
# 1692    Barcelona               5  Sarrià-Sant Gervasi          26
# 5246    Barcelona               9          Sant Andreu          60
#
#                    Nom_Barri                 Url_Preferent  Any_Constitucio  \
# 1692  Sant Gervasi - Galvany          http://www.ichh.net/             1600
# ...

# %% [markdown]
# --------

# %% [markdown]
# - 3 entidades (Dragons Gaming, Plataforma Ciudadana Millorem El Camp de L'Arpa, C.A. Salvem El Guinardó):
#     * no tienen NIF
#     * no tienen Forma Jurídica Indetificada
#     * tienen Tipología_E_GF: Grupo de hecho GF, siendo el resto E
#     * tienen Tipo de actividad: "Permanente", el resto no la tienen identificada

# %%
df_entidades["Tipologia_E_GF"].value_counts()
# Out:
# E     5481
# GF       3
# Name: Tipologia_E_GF, dtype: int64

# %%
df_entidades["Tipus_Activitat"].value_counts()
# Out:
# permanent    3
# Name: Tipus_Activitat, dtype: int64

# %% [markdown]
# Identifquemos cuales son las 3:

# %%
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas

# %%
df_entidades_actividad_permanente = df_entidades.loc[df_entidades["Tipus_Activitat"] == "permanent"]
df_entidades_actividad_permanente
# Out:
#      Tipologia_E_GF  Nif  Total_Voluntaris  Total_Professionals  \
# 5481             GF  NaN               NaN                  NaN
# 5482             GF  NaN               NaN                  NaN
# 5483             GF  NaN               NaN                  NaN
#
#      Tipus_Activitat Forma_Juridica  Codi_E_GF  \
# 5481       permanent            NaN         89
# 5482       permanent            NaN         87
# 5483       permanent            NaN         86
#
#                                              Nom_E_GF Nom_Popular  \
# 5481                                   Dragons Gaming         NaN
# 5482  Plataforma Ciutadana Millorem El Camp de l'Arpa         NaN
# 5483                          C.A. Salvem El Guinardó         NaN
#
#      Nom_Poblacio  Codi_Districte   Nom_Districte  Codi_Barri  \
# 5481    Barcelona               6          Gràcia          32
# 5482    Barcelona              10      Sant Martí          64
# ...

# %% [markdown]
# ------------

# %% [markdown]
# - 9 entidades:
#     * tienen el total de profesionales identificado, el resto no

# %%
df_entidades_profesionales_identificados = df_entidades.loc[df_entidades["Total_Professionals"].notna()]
df_entidades_profesionales_identificados
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 2087              E  V58343849              20.0                  1.0
# 2343              E  G63566467              40.0                  4.0
# 3229              E  G58441312              30.0                  1.0
# 3610              E  G08943813               NaN                170.0
# 3720              E  G58071507              32.0                 61.0
# 5441              E  G65727901               NaN                  7.0
# 5442              E  G58085960               NaN                  3.0
# 5453              E  G61459210              15.0                  4.0
# 5474              E  G24815664              50.0                  5.0
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 2087             NaN     Associació  99400184085
# 2343             NaN     Associació  99400172854
# 3229             NaN     Associació  94028141926
# 3610             NaN     Associació  92086022186
# ...

# %% [markdown]
# --------

# %% [markdown]
# - 10 entidades:
#     * tienen el total de voluntarios indetificado, el resto no

# %%
df_entidades_voluntarios_identificados = df_entidades.loc[df_entidades["Total_Voluntaris"].notna()]
df_entidades_voluntarios_identificados
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 2087              E  V58343849              20.0                  1.0
# 2343              E  G63566467              40.0                  4.0
# 3229              E  G58441312              30.0                  1.0
# 3720              E  G58071507              32.0                 61.0
# 5410              E  G85875409              11.0                  NaN
# 5446              E  G44873875               4.0                  NaN
# 5453              E  G61459210              15.0                  4.0
# 5461              E  G65506917              35.0                  NaN
# 5468              E  G65601239              35.0                  NaN
# 5474              E  G24815664              50.0                  5.0
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 2087             NaN     Associació  99400184085
# 2343             NaN     Associació  99400172854
# ...

# %% [markdown]
# ------------------

# %% [markdown]
# - 11 entidades:
#     * tienen sector territorial: "specific_districts", el resto "Barcelona" (3963) o no identificado (1510)

# %%
df_entidades["Sector_Territorial"].value_counts()
# Out:
# barcelona             3963
# specific_districts      11
# Name: Sector_Territorial, dtype: int64

# %%
df_entidades_sector_specificdist = df_entidades.loc[df_entidades["Sector_Territorial"] == "specific_districts"]
df_entidades_sector_specificdist
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 3229              E  G58441312              30.0                  1.0
# 3610              E  G08943813               NaN                170.0
# 5430              E  G66260712               NaN                  NaN
# 5434              E  G66202060               NaN                  NaN
# 5448              E  G67598441               NaN                  NaN
# 5451              E  G58643081               NaN                  NaN
# 5459              E  G59182766               NaN                  NaN
# 5461              E  G65506917              35.0                  NaN
# 5462              E  G09877648               NaN                  NaN
# 5482             GF        NaN               NaN                  NaN
# 5483             GF        NaN               NaN                  NaN
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 3229             NaN     Associació  94028141926
# ...

# %% [markdown]
# ----------------

# %% [markdown]
# - 11 entidades:
#     * tienen nombre popular indetificado, el resto no

# %%
df_entidades_nom_popular = df_entidades.loc[df_entidades["Nom_Popular"].notna()]
df_entidades_nom_popular
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 2343              E  G63566467              40.0                  4.0
# 3610              E  G08943813               NaN                170.0
# 3720              E  G58071507              32.0                 61.0
# 5410              E  G85875409              11.0                  NaN
# 5433              E  F01909373               NaN                  NaN
# 5438              E  G44965960               NaN                  NaN
# 5443              E  G66712696               NaN                  NaN
# 5459              E  G59182766               NaN                  NaN
# 5460              E  G10972099               NaN                  NaN
# 5461              E  G65506917              35.0                  NaN
# 5474              E  G24815664              50.0                  5.0
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 2343             NaN     Associació  99400172854
# ...

# %% [markdown]
# ------------------

# %% [markdown]
# - 1 entidad:
#     * que como nombre pone "no publicar test canviat". probablemente no debería estar en la base de datos.

# %% [markdown]
# Observamos que hay una que en nombre tiene una indicación "no publicar test canviat".

# %%
df_entidades_no_publicar = df_entidades.loc[df_entidades["Nom_E_GF"] == "no publicar test canviat"]
df_entidades_no_publicar
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 5474              E  G24815664              50.0                  5.0
#
#      Tipus_Activitat Forma_Juridica  Codi_E_GF                  Nom_E_GF  \
# 5474             NaN     Associació        227  no publicar test canviat
#
#      Nom_Popular  Sigla Nom_Poblacio  Codi_Districte        Nom_Districte  \
# 5474       no pu  SIGLA    Barcelona               5  Sarrià-Sant Gervasi
#
#       Codi_Barri                              Nom_Barri Url_Preferent  \
# 5474          22  Vallvidrera, el Tibidabo i les Planes           NaN
#
#       Any_Constitucio Sector_Territorial  Total_Socis Telefon_Preferent  \
# 5474             2006          barcelona        500.0         654321987
#
#          Correu_Preferent Sector_Tematic_1 Sector_Tematic_2 Sector_Tematic_3  \
# 5474  jordi.miro@hexar.es       Esportives              NaN              NaN
#
# ...

# %% [markdown]
# --------------------

# %% [markdown]
# **Algunos gaficos básicos:**

# %% [markdown]
# Veamos la distribución de entidades en Barcelona:

# %%
df_entidades["Forma_Juridica"].value_counts()
# Out:
# Associació                 4728
# Fundació                    383
# Altres                      178
# Cooperativa                 141
# Col·legis professionals      19
# Partit / Sindicat            17
# Gremis                       15
# Name: Forma_Juridica, dtype: int64

# %%
forma_juridica_counts = df_entidades["Forma_Juridica"].value_counts()

plt.figure(figsize=(10, 6))
forma_juridica_counts.plot(kind='bar')

plt.xlabel('Forma Jurídica')
plt.ylabel('Cantidad')
plt.title('Distribución de Formas Jurídicas')

plt.show()

# %%
df_entidades["Sector_Tematic_1"].value_counts()
# Out:
# Culturals                                           1502
# Educació i formació                                  659
# Esportives                                           510
# Suport social                                        270
# Cooperació al desenvolupament, Solidaritat i Pau     264
# Salut                                                253
# Veïnals                                              239
# Gremis i professionals                               228
# Juvenils                                             176
# Promoció de la ciutadania activa                     157
# Discapacitats                                        152
# Dones                                                150
# Religioses                                           139
# Ecologistes i mediambientals                         123
# Gent gran                                            122
# Economia social                                      105
# ...

# %%
Entidades_sector_1_counts = df_entidades["Sector_Tematic_1"].value_counts()
plt.figure(figsize=(10, 6))
Entidades_sector_1_counts.plot(kind='bar')

plt.xlabel('Temas')
plt.ylabel('Cantidad')
plt.title('Distribución por temas en Sector Tematic 1')

plt.show()

# %%
df_entidades["Sector_Tematic_2"].value_counts()
# Out:
# Promoció de la ciutadania activa                    210
# Suport social                                       188
# Culturals                                           187
# Educació i formació                                 186
# Juvenils                                            102
# Entitats de segon grau                               79
# Immigració                                           61
# Cooperació al desenvolupament, Solidaritat i Pau     59
# Drets Humans                                         57
# Dones                                                49
# Ecologistes i mediambientals                         49
# Salut                                                47
# Economia social                                      43
# Esportives                                           42
# Discapacitats                                        38
# Veïnals                                              36
# Gent gran                                            34
# ...

# %%
Entidades_sector_2_counts = df_entidades["Sector_Tematic_2"].value_counts()
plt.figure(figsize=(10, 6))
Entidades_sector_2_counts.plot(kind='bar')

plt.xlabel('Temas')
plt.ylabel('Cantidad')
plt.title('Distribución por temas en Sector Tematic 2')

plt.show()

# %%
df_entidades["Sector_Tematic_3"].value_counts()
# Out:
# Educació i formació                                 110
# Promoció de la ciutadania activa                     91
# Suport social                                        75
# Culturals                                            52
# Juvenils                                             47
# Drets Humans                                         33
# Cooperació al desenvolupament, Solidaritat i Pau     32
# Immigració                                           31
# Economia social                                      27
# Entitats de segon grau                               27
# Veïnals                                              22
# Salut                                                16
# Dones                                                16
# Esportives                                           13
# Ecologistes i mediambientals                         12
# Gent gran                                            11
# Comunicació                                          11
# ...

# %%
Entidades_sector_3_counts = df_entidades["Sector_Tematic_3"].value_counts()
plt.figure(figsize=(10, 6))
Entidades_sector_3_counts.plot(kind='bar')

plt.xlabel('Temas')
plt.ylabel('Cantidad')
plt.title('Distribución por temas en Sector Tematic 3')

plt.show()

# %%
Entidades_sector_1_counts = df_entidades["Sector_Tematic_1"].value_counts()
Entidades_sector_2_counts = df_entidades["Sector_Tematic_2"].value_counts()
Entidades_sector_3_counts = df_entidades["Sector_Tematic_3"].value_counts()

# Combino las tres series en una sola, poniendo cero donde no tenga alguno de los temas de la serie
series = Entidades_sector_1_counts.add(Entidades_sector_2_counts, fill_value=0).add(Entidades_sector_3_counts, fill_value=0)

#la ordeno de mayor a menor
series_ordenadas = series.sort_values(ascending=False)
series_ordenadas
# Out:
# Culturals                                           1741
# Educació i formació                                  955
# Esportives                                           565
# Suport social                                        533
# Promoció de la ciutadania activa                     458
# Cooperació al desenvolupament, Solidaritat i Pau     355
# Juvenils                                             325
# Salut                                                316
# Veïnals                                              297
# Gremis i professionals                               263
# Dones                                                215
# Discapacitats                                        197
# Immigració                                           193
# Ecologistes i mediambientals                         184
# Economia social                                      175
# Gent gran                                            167
# ...

# %%
# Obtengo una lista de todos los temas a partir del indice de la serie que he combinado
temas_unicos = series_ordenadas.index.tolist()

# Creo un DataFrame donde cada fila es un tema y hay una columna por sector. Relleno con los valores de las series y poniendo cero donde no hay valor
data = {
    "Sector Tematic 1": Entidades_sector_1_counts.reindex(temas_unicos, fill_value=0),
    "Sector Tematic 2": Entidades_sector_2_counts.reindex(temas_unicos, fill_value=0),
    "Sector Tematic 3": Entidades_sector_3_counts.reindex(temas_unicos, fill_value=0)
}

df = pd.DataFrame(data)
df
# Out:
#                                                   Sector Tematic 1  \
# Culturals                                                     1502
# Educació i formació                                            659
# Esportives                                                     510
# Suport social                                                  270
# Promoció de la ciutadania activa                               157
# Cooperació al desenvolupament, Solidaritat i Pau               264
# Juvenils                                                       176
# Salut                                                          253
# Veïnals                                                        239
# Gremis i professionals                                         228
# Dones                                                          150
# Discapacitats                                                  152
# Immigració                                                     101
# ...

# %%
# Creo el gráfico de barras apiladas
plt.figure(figsize=(16, 12))
df.plot(kind="bar", stacked=True)

plt.xlabel("Temas")
plt.ylabel("Cantidad")
plt.title("Entidades por Temas y Sector Tematic")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **En relación al número de voluntarios, Profesionales y socios:**

# %%
def Estad(columna):
    filtro = df_entidades.loc[df_entidades[columna].notna()]  # Filtro valores no nulos en la columna
    filtrado = filtro[columna]  # Selecciono la columna filtrada
    
    fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5)) 
    fig.subplots_adjust(wspace=1)  # Cambia el espacio horizontal entre subplots para separarlos un poco  
    
    # Grafico los estadísticos
    ax1.set_title("Estadísticas")
    ax1.axis("off")  # Elimino ejes y ticks
    ax1.text(0.5, 0.5, str(filtrado.describe()), fontsize=14, ha="center", va="center")
    
    # Segundo gráfico (Boxplot)
    ax2.set_title("Distribución de " + columna)
    ax2.boxplot(filtrado, vert=False)  # vert=False para que lo dibuje horizontal
    ax2.set_xlabel(columna)
   
    # Tercer gráfico (Histograma)
    ax3.set_title("Histograma")
    ax3.hist(filtrado, bins=100)  #escojo 100 intervalos para el histograma
    ax3.set_xlabel(columna)
    ax3.set_ylabel("Entidades", rotation="vertical")  #Rotacion vertical del texto
    

    plt.tight_layout()  # Ajustar el diseño de los gráficosque para evitar superposiciones
    plt.show()

# %%
Estad("Total_Voluntaris")

# %%
df_entidades.loc[df_entidades["Total_Voluntaris"]==50]
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 5474              E  G24815664              50.0                  5.0
#
#      Tipus_Activitat Forma_Juridica  Codi_E_GF                  Nom_E_GF  \
# 5474             NaN     Associació        227  no publicar test canviat
#
#      Nom_Popular  Sigla Nom_Poblacio  Codi_Districte        Nom_Districte  \
# 5474       no pu  SIGLA    Barcelona               5  Sarrià-Sant Gervasi
#
#       Codi_Barri                              Nom_Barri Url_Preferent  \
# 5474          22  Vallvidrera, el Tibidabo i les Planes           NaN
#
#       Any_Constitucio Sector_Territorial  Total_Socis Telefon_Preferent  \
# 5474             2006          barcelona        500.0         654321987
#
#          Correu_Preferent Sector_Tematic_1 Sector_Tematic_2 Sector_Tematic_3  \
# 5474  jordi.miro@hexar.es       Esportives              NaN              NaN
#
# ...

# %% [markdown]
# Observamos que aunque la media de Voluntarios declarados esta alrededor de 27, siendo 4 voluntarios el mínimo declarado, el 50% de las entidades tienen menos de 31 voluntarios, y el 75% menos de 35.
# El máximo de 50 voluntarios lo da precisamente la que indican como nombre_E_GF **"no publicar test canviat"**, con mail **jordi.miro@hexar.es** que tiene 500 socios y 5 profesionales.

# %% [markdown]
# Si no cosnideraramos este último tendríamos:

# %%
df_entidades_sin_outlier50_voluntaris  = df_entidades[df_entidades["Total_Voluntaris"] <50]

# %%
filtro = df_entidades_sin_outlier50_voluntaris.loc[df_entidades_sin_outlier50_voluntaris["Total_Voluntaris"].notna()]  # Filtro valores no nulos en la columna
filtrado = filtro["Total_Voluntaris"]  # Selecciono la columna filtrada
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5)) 
fig.subplots_adjust(wspace=1)  # Cambia el espacio horizontal entre subplots para separarlos un poco  
ax1.set_title("Estadísticas")
ax1.axis("off")  # Elimino ejes y ticks
ax1.text(0.5, 0.5, str(filtrado.describe()), fontsize=14, ha="center", va="center")
ax2.set_title("Distribución de Total_Voluntaris sin outlier50")
ax2.boxplot(filtrado, vert=False)  # vert=False para que lo dibuje horizontal
ax2.set_xlabel("Total_Voluntaris")
ax3.set_title("Histograma")
ax3.hist(filtrado, bins=100)  #escojo 100 intervalos para el histograma
ax3.set_xlabel("Total_Voluntaris")
ax3.set_ylabel("Entidades", rotation="vertical")  #Rotacion vertical del texto
plt.tight_layout()  # Ajustar el diseño de los gráficosque para evitar superposiciones
plt.show()

# %% [markdown]
# Donde observamos que aunque la media de Voluntarios declarados esta alrededor de 24, siendo 4 voluntarios el mínimo declarado, el 50% de las entidades tienen 30 voluntarios o menos, y el 75% tienen 35 o menos, con un máximo de 40.

# %% [markdown]
# ----------

# %%
Estad("Total_Professionals")

# %% [markdown]
# A pesar de que el Boxplot me dice que los outliers estan por encima de 50, voy a calcular el valor de outlier formal, con scipy:

# %%
# Filtro los valores NaN en la columna "Total_Professionals"
entidades_filtradas = df_entidades["Total_Professionals"].dropna()

# Calculo el rango intercuartil (IQR) para los valores filtrados con scipy
IQR = iqr(entidades_filtradas)

# Calcula el límite superior para identificar outliers
Outlier_superior = entidades_filtradas.quantile(0.75) + 1.5 * IQR
Outlier_superior
# Out:
# 13.0

# %%
df_entidades.loc[df_entidades["Total_Professionals"]>=13]
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 3610              E  G08943813               NaN                170.0
# 3720              E  G58071507              32.0                 61.0
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 3610             NaN     Associació  92086022186
# 3720             NaN       Fundació  92086015086
#
#                                                Nom_E_GF  Nom_Popular Sigla  \
# 3610                    ASSOCIACIO ESPORTIVA L'EIXAMPLE  AE EIXAMPLE   NaN
# 3720  La Tutela, Fundació privada catalana tutelar d...    La Tutela   NaN
#
#      Nom_Poblacio  Codi_Districte Nom_Districte  Codi_Barri  \
# 3610    Barcelona               2      Eixample           9
# 3720    Barcelona               6        Gràcia          32
#
#                                Nom_Barri                Url_Preferent  \
# 3610      la Nova Esquerra de l'Eixample  https://www.ae-eixample.cat
# ...

# %% [markdown]
# Vemos que hay una entidad con 61 profesionales (**La Tutela, Fundació privada catalana tutelar discapacitat intel·lectual i/o amb deteriorament cognitiu** sin socios declarados y con 32 voluntarios, y una de 170 (la **Associacio Esportiva L'Eixample**) con 32 socios y sin voluntarios declarados.

# %% [markdown]
# Suponiendo ques e trata de outliers que desvirtuan la media, si no los consideramos tendremos:

# %%
df_entidades_sin_outlier_prof = df_entidades[df_entidades["Total_Professionals"] <=50]

# %%
filtro = df_entidades_sin_outlier_prof.loc[df_entidades_sin_outlier_prof["Total_Professionals"].notna()]  # Filtro valores no nulos en la columna
filtrado = filtro["Total_Professionals"]  # Selecciono la columna filtrada
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5)) 
fig.subplots_adjust(wspace=1)  # Cambia el espacio horizontal entre subplots para separarlos un poco  
ax1.set_title("Estadísticas")
ax1.axis("off")  # Elimino ejes y ticks
ax1.text(0.5, 0.5, str(filtrado.describe()), fontsize=14, ha="center", va="center")
ax2.set_title("Distribución de Total_Professionals sin outliers")
ax2.boxplot(filtrado, vert=False)  # vert=False para que lo dibuje horizontal
ax2.set_xlabel("Total_Professionals")
ax3.set_title("Histograma")
ax3.hist(filtrado, bins=100)  #escojo 100 intervalos para el histograma
ax3.set_xlabel("Total_Professionals")
ax3.set_ylabel("Entidades", rotation="vertical")  #Rotacion vertical del texto
plt.tight_layout()  # Ajustar el diseño de los gráficosque para evitar superposiciones
plt.show()

# %% [markdown]
# Tenemos una media de 3,5 Profesionales declarados por Entidad con un mínimo declarado de 1 y un 75% con 4.5 o menos, y un maximo de 7, excepto las siguientes dos fundaciones:
# - **La Tutela, Fundació privada catalana tutelar discapacitat intel·lectual i/o amb deteriorament cognitiu** con 61 profesionales, sin socios declarados y con 32 voluntarios,
# - **Associacio Esportiva L'Eixample** con 170 profesionales, con 32 socios y sin voluntarios declarados

# %% [markdown]
# ------------

# %%
Estad("Total_Socis")

# %% [markdown]
# Veamos los outliers:

# %%
# Filtro los valores NaN en la columna "Total_Professionals", obteniendo una serie con los valores de esta columna
entidades_filtradas = df_entidades["Total_Socis"].dropna()

# Calculo el rango intercuartil (IQR) para los valores filtrados con scipy
IQR = iqr(entidades_filtradas)

# Calcula el límite superior para identificar outliers
Outlier_superior = entidades_filtradas.quantile(0.75) + 1.5 * IQR
Outlier_superior
# Out:
# 602.5

# %% [markdown]
# En el caso de que no consideremos los outliers con 600 socios o mas, tenemos:

# %%
df_entidades_sin_outlier_socis = df_entidades[df_entidades["Total_Socis"] <=600]

# %%
filtro = df_entidades_sin_outlier_socis.loc[df_entidades_sin_outlier_socis["Total_Socis"].notna()]  # Filtro valores no nulos en la columna
filtrado = filtro["Total_Socis"]  # Selecciono la columna filtrada
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5)) 
fig.subplots_adjust(wspace=1)  # Cambia el espacio horizontal entre subplots para separarlos un poco  
ax1.set_title("Estadísticas")
ax1.axis("off")  # Elimino ejes y ticks
ax1.text(0.5, 0.5, str(filtrado.describe()), fontsize=14, ha="center", va="center")
ax2.set_title("Distribución de Total_Socis <600 socios")
ax2.boxplot(filtrado, vert=False)  # vert=False para que lo dibuje horizontal
ax2.set_xlabel("Total_Socis")
ax3.set_title("Histograma")
ax3.hist(filtrado, bins=100)  #escojo 100 intervalos para el histograma
ax3.set_xlabel("Total_Socis")
ax3.set_ylabel("Entidades", rotation="vertical")  #Rotacion vertical del texto
plt.tight_layout()  # Ajustar el diseño de los gráficosque para evitar superposiciones
plt.show()

# %% [markdown]
# Observamos que de 1.336 entidades, 1.183 entidades (88,5%) tienen menos de 600 socios con una media de 110, con un mínimo de 2 y un máximo de 600, teneiendo el 50% un total de 50 socios o menos y el 75% menos o igual que 155 socios.

# %%
df_entidades_outlier_socis = df_entidades[df_entidades["Total_Socis"] >600]

# %%
filtro = df_entidades_outlier_socis.loc[df_entidades_outlier_socis["Total_Socis"].notna()]  # Filtro valores no nulos en la columna
filtrado = filtro["Total_Socis"]  # Selecciono la columna filtrada
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5)) 
fig.subplots_adjust(wspace=1)  # Cambia el espacio horizontal entre subplots para separarlos un poco  
ax1.set_title("Estadísticas")
ax1.axis("off")  # Elimino ejes y ticks
ax1.text(0.5, 0.5, str(filtrado.describe()), fontsize=14, ha="center", va="center")
ax2.set_title("Distribución de Total_Socis >600 socios")
ax2.boxplot(filtrado, vert=False)  # vert=False para que lo dibuje horizontal
ax2.set_xlabel("Total_Socis")
ax3.set_title("Histograma")
ax3.hist(filtrado, bins=100)  #escojo 100 intervalos para el histograma
ax3.set_xlabel("Total_Socis")
ax3.set_ylabel("Entidades", rotation="vertical")  #Rotacion vertical del texto
plt.tight_layout()  # Ajustar el diseño de los gráficosque para evitar superposiciones
plt.show()

# %% [markdown]
# Observamos que de 1.336 entidades,153 entidades (11,5%) tienen mas de 600 socios con una media de 8.922, con un mínimo de 606 y un máximo de 300.000, teniendo el 50% un total de 1.600 socios o menos y 2.971 o menos para el 75%.

# %%
Total_socios = entidades_filtradas.sum()  #Calculo la suma total de socios
entidades153_filtradas = df_entidades_outlier_socis["Total_Socis"].dropna()  #Creo una lista con los valores de "Total Socis"
Total_153entidades_socios = entidades153_filtradas.sum()  #Sumo el total de socios acumulados con las 153.
print("Las 153 entidades seleccionadas acumulan el {}% del total de socios".format(round(Total_153entidades_socios / Total_socios * 100, 2)))
# Out:
# Las 153 entidades seleccionadas acumulan el 91.24% del total de socios

# %%
df_entidades.describe().round(2)
# Out:
#        Total_Voluntaris  Total_Professionals     Codi_E_GF  Codi_Districte  \
# count             10.00                 9.00  5.484000e+03         5484.00
# mean              27.20                28.44  8.379581e+10            4.89
# std               14.29                56.41  2.916941e+10            3.11
# min                4.00                 1.00  8.600000e+01            1.00
# 25%               16.25                 3.00  9.208600e+10            2.00
# 50%               31.00                 4.00  9.940003e+10            5.00
# 75%               35.00                 7.00  9.940026e+10            8.00
# max               50.00               170.00  9.988801e+10           10.00
#
#        Codi_Barri  Any_Constitucio  Total_Socis  Codi_tipus_via  Codi_Carrer  \
# count     5484.00          5484.00      1336.00         5482.00      5482.00
# mean        27.62          1826.54      1119.91            4.43    206165.33
# ...

# %% [markdown]
# ------------

# %% [markdown]
# **Veamos la dsitribución de entidades creadas por año**

# %%
df_entidades_xaño = df_entidades.groupby("Any_Constitucio")

# %% [markdown]
# **Resumen del análisis previo de la base de datos de entidades.
# De 5484 entidades**:
#
# **1 entidad:**
#     - no tiene indetificado el Sector temático 1 (se trata de la **Parròquia Sant paulí de Nola**)
#     - tiene nombre de Poblacion fuera de Barcelona: Badía del Vallés (se trata de la **Federació Catalana de Judo i Disciplines Assoc..**), pero en distrito indican Sant Gervais, asi que asumo que se trata de un error y que está en Barcelona.
#     - tiene por nombre: **"no publicar test canviat"**. probablemente no debería estar en la base de datos.
#
#
# **2 entidades** (**Fundación Colegio de Huérfanos de Hacienda** y **Associació Catalana de Malalties Neuromusculars**) no tienen forma de localizarse físicamente al faltar:
#     - Codigo Tipo de Via
#     - Tipo de via
#     - Codigo de Calle
#     - Nombre de la calle
#     - Código de número de calle
#     - Número de calle
#     - Latitud
#     - Longitud
#     - X_ETRS89
#     - Y_ETRS89
#
# **3 entidades** (**Dragons Gaming**, **Plataforma Ciudadana Millorem El Camp de L'Arpa**, **C.A. Salvem El Guinardó**):
#     - no tienen NIF
#     - no tienen Forma Jurídica Indetificada
#     - tienen Tipología_E_GF: Grupo de hecho GF, siendo el resto E
#     - tienen Tipo de actividad: "Permanente", el resto no la tienen identificada
#
# **9 entidades:**
#     - tienen el total de **profesionales** identificado (ver la tabla arriba), el resto no
#
# Tenemos una media de 3,5 Profesionales declarados por Entidad con un mínimo declarado de 1 y un 75% con 4.5 o menos, y un maximo de 7, excepto las siguientes dos entidades:
# - **La Tutela, Fundació privada catalana tutelar discapacitat intel·lectual i/o amb deteriorament cognitiu** con 61 profesionales, sin socios declarados y con 32 voluntarios,
# - **Associacio Esportiva L'Eixample** con 170 profesionales, con 32 socios y sin voluntarios declarados
# ![image-18.png](attachment:image-18.png)
# ![image-12.png](attachment:image-12.png)
#
# **10 entidades:**
#     - tienen el total de **voluntarios** indetificado (ver la tabla arriba), el resto no
#
# Observamos que aunque la media de Voluntarios declarados esta alrededor de 24, siendo 4 voluntarios el mínimo declarado, el 50% de las entidades tienen 30 voluntarios o menos, y el 75% tienen 35 o menos, con un máximo de 40.
#
# Tenemos un outlier con 50 voluntarios en el que indican como nombre_E_GF **"no publicar test canviat"**, con mail jordi.miro@hexar.es, que además tiene 500 socios y 5 profesionales.
# ![image-10.png](attachment:image-10.png)
# ![image-17.png](attachment:image-17.png)
#
# **11 entidades:**
#     - tienen nombre popular indetificado (ver la tabla arriba), el resto no
#     - tienen sector territorial: "specific_districts" (ver la tabla arriba), el resto "Barcelona" (3963) o no identificado (1510)
#
#
# **Solo:**
#     - 988 tienen Siglas (18%)
#     - 1590 tienen el sector temático 2 identificado (29%)
#     - 655 tienen el sector temático 3 identificado (12%)
#
# **1336** tienen el número total de socios identificados (24%), habiendo desde **2** socios hasta **300.000**:
#  ![image-13.png](attachment:image-13.png)
#
#  En el caso de que no consideremos los outliers con 600 socios o mas, observamos que de 1.336 entidades, 1.183 entidades (88,5%) tienen menos de 600 socios con una media de 110, con un mínimo de 2 y un máximo de 600, teneiendo el 50% un total de 50 socios o menos y el 75% menos o igual que 155 socios.
# ![image-15.png](attachment:image-15.png)
#
#  Observamos por tanto, que 153 entidades (11,5%) tienen mas de 600 socios con una media de 8.922, con un mínimo de 606 y un máximo de 300.000, acumulando el **91.24%** del total de socios.
# ![image-16.png](attachment:image-16.png)
#
#
#
# **Esta es  la distribución de entidades por Forma jurdícia:**
#  ![image-5.png](attachment:image-5.png)
#
# **En relación a los sectores temáticos:**
#  1) Esta es la distribución por sector tematico de las entidades:
#  ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)
#  2) Donde observamos en el grafico apilado la siguiente distribución por sector y tema:
#  ![image-4.png](attachment:image-4.png)
#
#
# **A nivel de presencia en redes solo:**
#     - 325 tienen Instagram (6%)
#     - 776 tienen Twitter (14%)
#     - 1099 tienen Facebook (20%)
#     - 291 estan en otras redes (5%)
#
# **A nivel de localización solo:**
#     - 232 tienen escalera identificada (4%)
#     - 2813 tienen el Piso idnetificado (51%)
#     - 1629 tienen la Puerta indetificada (3%)
#
# **Adicionalmente:**
#     - 2938 tienen URL prefernet identificada (53%)
#     - 3974 tienen Sector territorial idnetificado (72%)
#     - 4694 tienen teléfono preferente identificado (84%)
#     - 4881 tienen correo preferente identificado (89%)
#
#
# **En el caso de los siguientes parámetros, todas las entidades los tienen identificados**:
#     - E_GF:
#         * Tipologia_E_GF
#         * Codi_E_GF
#         * Nom_E_GF
#     - Localización general:
#         * Nombre de Población
#         * Código de Distrito
#         * Nombre de Distrito
#         * Código de Barrio
#         * Nombre de Barrio
#     - Año de constitución donde hay entidades constituidas desde el **1380** hasta el **2023**.
#
# Verificaremos la distribución de entidades y subvenciones por Distrito o Barrio y el año de cosntitución (por antiguedad).
# **Dado que el fichero de subvenciones es temporal desde el 2011 hasta el 2022, eliminaremos del analisis las creadas en el 2023.**

# %% [markdown]
# **Eliminamos columnas del df_entidades que no voy a ultilizar (del df_subvenciones utilizaré, a priori, todas)**:
#
# 20.**Telefon_Preferent**: Telèfon preferent de contacte
# 21.**Correu_Preferent**: Adreça preferent de correu electrònic
# 29.**Codi_tipus_via**: Codi tipus via codificat AjBCN
# 30.**Tipus_Via**: Tipus via
# 31.**Codi_Carrer**: Codi carrer codificació AjBCN
# 32.**Nom_Carrer**: Nom del carrer
# 33.**Codi_número_carrer**: Codi número carrer codificació AjBCN
# 34.**Numero_Carrer**: Número
# 35.**Escala**: Escala
# 36.**Pis**: Pis
# 37.**Porta**: Porta 38.Latitud: Latitud
# 39.**Longitud**: Longitud
# 40.**X_ETRS89**: Coordenada X en ETRS89
# 41.**Y_ETRS89**: Coordenada Y en ETRS89

# %%
df_entidades.drop(columns=["Sigla", "Telefon_Preferent", "Correu_Preferent", "Codi_tipus_via", "Tipus_Via", "Codi_Carrer", "Nom_Carrer", "Codi_número_carrer", "Numero_Carrer", "Escala", "Pis", "Porta", "Latitud", "Longitud", "X_ETRS89", "Y_ETRS89"], inplace=True)
df_entidades.head()   #He añadido inplace=True para que me escriba directamente en el mismo df.
# Out:
#   Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 0              E  G66024894               NaN                  NaN
# 1              E  R0800530H               NaN                  NaN
# 2              E  G08489528               NaN                  NaN
# 3              E  G01675180               NaN                  NaN
# 4              E  F67141648               NaN                  NaN
#
#   Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 0             NaN     Associació  99888005242
# 1             NaN     Associació  99746315497
# 2             NaN       Fundació  99739953046
# 3             NaN     Associació  99674314027
# 4             NaN    Cooperativa  99564110147
#
#                                     Nom_E_GF Nom_Popular Nom_Poblacio  ...  \
# 0  Associació d'Afectats d'Urticària Crònica         NaN    Barcelona  ...
# 1           Parròquia Sant Ignasi de Loiola          NaN    Barcelona  ...
# ...

# %%
df_entidades.shape
# Out:
# (5484, 25)

# %% [markdown]
# **Añadimos una columna que sea 1 si tienen presencia en redes y 0 si no**.

# %%
# Utilizo .notna() para verificar si cada columna tiene un valor no nulo y el operador | = OR entre las condiciones de cada columna. 
# Convierto el resultado en 0 o 1 utilizando de las codniciones de las columnas .astype(int) y lo va asignando a la celda de la columna "Presencia_redes"
df_entidades["Presencia_redes"] = (df_entidades["XXSS_Instagram"].notna() | 
                                df_entidades["XXSS_Twitter"].notna() |
                                df_entidades["XXSS_Facebook"].notna() |
                                df_entidades["XXSS_Altres"].notna()).astype(int) 
df_entidades.head()
# Out:
#   Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 0              E  G66024894               NaN                  NaN
# 1              E  R0800530H               NaN                  NaN
# 2              E  G08489528               NaN                  NaN
# 3              E  G01675180               NaN                  NaN
# 4              E  F67141648               NaN                  NaN
#
#   Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 0             NaN     Associació  99888005242
# 1             NaN     Associació  99746315497
# 2             NaN       Fundació  99739953046
# 3             NaN     Associació  99674314027
# 4             NaN    Cooperativa  99564110147
#
#                                     Nom_E_GF Nom_Popular Nom_Poblacio  ...  \
# 0  Associació d'Afectats d'Urticària Crònica         NaN    Barcelona  ...
# 1           Parròquia Sant Ignasi de Loiola          NaN    Barcelona  ...
# ...

# %%
df_entidades.shape
# Out:
# (5484, 26)

# %% [markdown]
# ### b. Subvenciones (2011-2022)

# %%
df_subvenciones = pd.read_csv("C:/Users/alpid/Downloads/SUBVENCIONS.csv")
df_subvenciones.head()
# Out:
#   Tipologia_E_GF    Codi_E_GF                     Entitat_Municipal  \
# 0              E          224               Ajuntament de Barcelona
# 1              E  99400147070  Institut Municipal Barcelona Esports
# 2              E          224               Ajuntament de Barcelona
# 3              E  99400173016  Institut Municipal Barcelona Esports
# 4              E          224               Ajuntament de Barcelona
#
#                                         Organ_Gestor   Any  \
# 0   Gerència de Política Econòmica i Desenvolupament  2019
# 1                                                NaN  2017
# 2   Gerència de Política Econòmica i Desenvolupament  2019
# 3                                                NaN  2017
# 4  Gerència d’Àrea d’Economia, Recursos i Promoci...  2022
#
#                               Tipologia_De_Subvencio  \
# 0                            SUBVENCIONS NOMINATIVES
# 1         SUBVENCIONS DIRECTES (amb o sense CONVENI)
# ...

# %% [markdown]
# **Igual que con df_entidades, voy a convertir todos los 0.0 en Nan para evitar errores:**

# %%
df_subvenciones = df_subvenciones.replace(0.0, np.nan)
df_subvenciones.head()
# Out:
#   Tipologia_E_GF    Codi_E_GF                     Entitat_Municipal  \
# 0              E          224               Ajuntament de Barcelona
# 1              E  99400147070  Institut Municipal Barcelona Esports
# 2              E          224               Ajuntament de Barcelona
# 3              E  99400173016  Institut Municipal Barcelona Esports
# 4              E          224               Ajuntament de Barcelona
#
#                                         Organ_Gestor   Any  \
# 0   Gerència de Política Econòmica i Desenvolupament  2019
# 1                                                NaN  2017
# 2   Gerència de Política Econòmica i Desenvolupament  2019
# 3                                                NaN  2017
# 4  Gerència d’Àrea d’Economia, Recursos i Promoci...  2022
#
#                               Tipologia_De_Subvencio  \
# 0                            SUBVENCIONS NOMINATIVES
# 1         SUBVENCIONS DIRECTES (amb o sense CONVENI)
# ...

# %%
df_subvenciones.shape
# Out:
# (56917, 11)

# %% [markdown]
# Se han producido 56917 subvenciones del 2011 al 2022.

# %%
df_subvenciones.isna().all()
# Out:
# Tipologia_E_GF             False
# Codi_E_GF                  False
# Entitat_Municipal          False
# Organ_Gestor               False
# Any                        False
# Tipologia_De_Subvencio     False
# Objecte                    False
# Import_Sollicitat          False
# Import_Total_Projecte      False
# Import_Atorgat_Inicial     False
# Import_Reintegrat_Total    False
# dtype: bool

# %% [markdown]
# No hay ninguna columna con sus valores 100% NaN.

# %% [markdown]
# Analicemos la base de datos:

# %%
df_subvenciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56917 entries, 0 to 56916
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tipologia_E_GF           56917 non-null  object
#  1   Codi_E_GF                56917 non-null  int64
#  2   Entitat_Municipal        56910 non-null  object
#  3   Organ_Gestor             51654 non-null  object
#  4   Any                      56917 non-null  int64
#  5   Tipologia_De_Subvencio   56917 non-null  object
#  6   Objecte                  56917 non-null  object
#  7   Import_Sollicitat        55437 non-null  float64
#  8   Import_Total_Projecte    56558 non-null  float64
#  9   Import_Atorgat_Inicial   56917 non-null  float64
#  10  Import_Reintegrat_Total  1485 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 4.8+ MB

# %%
df_subvenciones.isna().sum()
# Out:
# Tipologia_E_GF                 0
# Codi_E_GF                      0
# Entitat_Municipal              7
# Organ_Gestor                5263
# Any                            0
# Tipologia_De_Subvencio         0
# Objecte                        0
# Import_Sollicitat           1480
# Import_Total_Projecte        359
# Import_Atorgat_Inicial         0
# Import_Reintegrat_Total    55432
# dtype: int64

# %%
df_subvenciones["Tipologia_E_GF"].value_counts()
# Out:
# E    56917
# Name: Tipologia_E_GF, dtype: int64

# %%
df_subvenciones["Entitat_Municipal"].value_counts()
# Out:
# Ajuntament de Barcelona                                       43400
# Institut de Cultura de Barcelona                               4197
# Institut Municipal Barcelona Esports                           4081
# Institut Barcelona Esports                                     2341
# Institut Municipal de persones amb Discapacitat                1354
# Institut Municipal de Serveis Socials                           698
# Institut Municipal d'Educació de Barcelona                      378
# Institut Municipal de Persones amb Discapacitat                 173
# Institut Municipal del Paisatge Urbà i la Qualitat de Vida      104
# Institut Municipal de Mercats de Barcelona                       89
# Institut Municipal d'Educació                                    59
# Institut Municipal d' Hisenda                                    36
# Name: Entitat_Municipal, dtype: int64

# %%
df_subvenciones["Organ_Gestor"].value_counts()
# Out:
# Gerència de Drets Socials                                                5533
# Institut de Cultura de Barcelona                                         3622
# Districte de Sant Martí                                                  3248
# Gerència Drets de Ciutadania, Participació i Transparència               3215
# Districte d'Horta-Guinardó                                               2974
# Gerència d'Area de Drets Socials, Justícia Global, Feminismes i LGTBI    2748
# Districte de Sants-Montjuic                                              2567
# Districte de Sant Andreu                                                 2415
# Districte de Ciutat Vella                                                2372
# Institut Barcelona Esports                                               2348
# Districte de l'Eixample                                                  2294
# Districte de Nou Barris                                                  2139
# ...

# %%
df_subvenciones["Any"].value_counts()
# Out:
# 2020    6395
# 2019    6267
# 2017    6119
# 2018    5913
# 2021    5888
# 2022    5853
# 2016    5081
# 2015    4479
# 2014    3951
# 2013    2655
# 2011    2571
# 2012    1745
# Name: Any, dtype: int64

# %%
df_subvenciones["Tipologia_De_Subvencio"].value_counts()
# Out:
# SUBVENCIONS DIRECTES (amb o sense CONVENI)                          5385
# AJUTS                                                               2800
# CONVOCATÒRIA GENERAL DE SUBVENCIONS 2017. CIUTADANIA I PARTICIPA     709
# SUBVENCIONS NOMINATIVES                                              685
# CONVOCATÒRIA GENERAL DE SUBVENCIONS 2020. GERÈNCIA DRETS SOCIALS     670
#                                                                     ...
# EXPEDIENT ORGAN GESTOR SARRIÀ-SANT GERVASI                             1
# PROJECTE PILOT AMUNT!                                                  1
# CONVOCATÒRIA SUBVENCIONS MANTENIMENT EMPRESES DELS SECTORS DE TU       1
# XVI edició Premi 25 de novembre                                        1
# CONCURS SALO EXPOSITIU 2022                                            1
# Name: Tipologia_De_Subvencio, Length: 346, dtype: int64

# %%
df_subvenciones["Objecte"].value_counts()
# Out:
# Ajut del programa Promoció i participació infància    1393
# Ajut del programa                                     1038
# Ajuts 2019-2020                                        461
# Ajuts 2020-2021                                        413
# Ajuts 2018-2019 (2n. pagament)                         217
#                                                       ...
# PROJECTE AMPA CEIP PATRONAT DOMENECH                     1
# FOMENT D'ACTIVITATS ANUALS AMPA                          1
# activitats educatives i culturals                        1
# INDEPENDENT -COMUNICACIO I GENERE                        1
# Premis Ciutat Barcelona 2017 Associació col.lectiu       1
# Name: Objecte, Length: 41424, dtype: int64

# %%
df_subvenciones["Import_Sollicitat"].sum()
# Out:
# 741804495.0

# %%
df_subvenciones["Import_Total_Projecte"].sum()
# Out:
# 1687444780.3400002

# %%
df_subvenciones["Import_Atorgat_Inicial"].sum()
# Out:
# 695718928.5799999

# %%
df_subvenciones["Import_Reintegrat_Total"].sum()
# Out:
# 4502431.41

# %%
df_subvenciones.describe().round(2)
# Out:
#           Codi_E_GF       Any  Import_Sollicitat  Import_Total_Projecte  \
# count  5.691700e+04  56917.00           55437.00               56558.00
# mean   8.506857e+10   2017.52           13381.04               29835.65
# std    2.838212e+10      3.11           72194.69              112986.62
# min    2.240000e+02   2011.00               0.60                   0.60
# 25%    9.208601e+10   2015.00            2000.00                4350.00
# 50%    9.631921e+10   2018.00            4500.00               10250.00
# 75%    9.940024e+10   2020.00           10000.00               25645.20
# max    9.988801e+10   2022.00         7697739.83            12248500.00
#
#        Import_Atorgat_Inicial  Import_Reintegrat_Total
# count                56917.00                  1485.00
# mean                 12223.39                  3031.94
# std                 111491.59                  9078.19
# min                -233195.97                     0.10
# ...

# %% [markdown]
# **Resumen del análisis previo de la base de datos de subvenciones.
# De 56917 subvenciones**:
#
# Vemos que en general todas las subvenciones realizadas tienen todos los datos excepto:
# * en 7 casos no tienen la entidad municipal indentificada.
# * en 5263 no tienen el Organo gestor identificado (9% de los casos)
# * en 1480 casos no consta elimporte solicitado (2,6% de los casos)
# * en 359 casos no consta el importe total del proyecto (0,6%)
# * en 55432 casos no consta reintegro de importe (97% de los casos)
#
# Teniendo en cuenta que en este caso se trata de datos historicos, deberemos comprobar si hay coincidencias por entidad en los casos donde no hay constancias.
#
# Observamos que:
# * Tipología_E_GF: todas son tipología E
#
# En relación a los importes:
# * Se ha solicitado 741.804.495 €, para un importe total de proyectos de 1.687.444.780 €, donde se ha otorgado un importe inicial de 695.718.928 €, y se ha reintegrado un total de 4.502.431 €.
#
# * Obervamos que hay valore negativos en el Importe otorgado incial asi que verificaremos si es un error. Tmabien observamos importes solicitados, de proyecto y reintegrados muy bajos que igualmente verificaremos si es un error.

# %% [markdown]
# ### c. Merge de las bases de datos

# %% [markdown]
# **Ahora voy a hacer un merge de los DataFrame como en SQL usando "outer"** para:
# - tener todas las entidades de subvencionadas con las columnas de df_entidades
# - y además tener las entidades no subvencionadas con ceros en las columnas que les corresponderían.

# %%
# Realizo la fusión (merge) en función de la columna que contiene la clave 'Codi_E_GF' 
df_merged = pd.merge(df_subvenciones, df_entidades, on='Codi_E_GF', how='outer')
df_merged.head()
# Out:
#   Tipologia_E_GF_x  Codi_E_GF        Entitat_Municipal  \
# 0                E        224  Ajuntament de Barcelona
# 1                E        224  Ajuntament de Barcelona
# 2                E        224  Ajuntament de Barcelona
# 3                E        224  Ajuntament de Barcelona
# 4                E        224  Ajuntament de Barcelona
#
#                                         Organ_Gestor     Any  \
# 0   Gerència de Política Econòmica i Desenvolupament  2019.0
# 1   Gerència de Política Econòmica i Desenvolupament  2019.0
# 2  Gerència d’Àrea d’Economia, Recursos i Promoci...  2022.0
# 3  Gerència d’Àrea d’Economia, Recursos i Promoci...  2021.0
# 4  Gerència d’Àrea d’Economia, Recursos i Promoci...  2020.0
#
#                               Tipologia_De_Subvencio  \
# 0                            SUBVENCIONS NOMINATIVES
# 1  Convocatòria Subvencions Promoció i Reforç Eco...
# 2  Convocatòria 2022 Impuls socioeconòmic del ter...
# ...

# %%
df_merged.shape
# Out:
# (58560, 36)

# %%
df_merged.describe()
# Out:
#           Codi_E_GF           Any  Import_Sollicitat  Import_Total_Projecte  \
# count  5.856000e+04  56917.000000       5.543700e+04           5.655800e+04
# mean   8.499931e+10   2017.523323       1.338104e+04           2.983565e+04
# std    2.848553e+10      3.110568       7.219469e+04           1.129866e+05
# min    8.600000e+01   2011.000000       6.000000e-01           6.000000e-01
# 25%    9.208601e+10   2015.000000       2.000000e+03           4.350000e+03
# 50%    9.702717e+10   2018.000000       4.500000e+03           1.025000e+04
# 75%    9.940024e+10   2020.000000       1.000000e+04           2.564520e+04
# max    9.988801e+10   2022.000000       7.697740e+06           1.224850e+07
#
#        Import_Atorgat_Inicial  Import_Reintegrat_Total  Total_Voluntaris  \
# count            5.691700e+04              1485.000000         92.000000
# mean             1.222339e+04              3031.940343         27.173913
# ...

# %% [markdown]
# ## 1) Profundizando el analisis básico:

# %% [markdown]
# Para este anaisis usaremos el DataFrame df_entidades generado.

# %%
df_entidades.head()
# Out:
#   Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 0              E  G66024894               NaN                  NaN
# 1              E  R0800530H               NaN                  NaN
# 2              E  G08489528               NaN                  NaN
# 3              E  G01675180               NaN                  NaN
# 4              E  F67141648               NaN                  NaN
#
#   Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 0             NaN     Associació  99888005242
# 1             NaN     Associació  99746315497
# 2             NaN       Fundació  99739953046
# 3             NaN     Associació  99674314027
# 4             NaN    Cooperativa  99564110147
#
#                                     Nom_E_GF Nom_Popular Nom_Poblacio  ...  \
# 0  Associació d'Afectats d'Urticària Crònica         NaN    Barcelona  ...
# 1           Parròquia Sant Ignasi de Loiola          NaN    Barcelona  ...
# ...

# %% [markdown]
# **Análisis básico**

# %% [markdown]
# En un primer analisis:
# Hemos visto que, 3 no tienen:
#     * NIF
#     * Forma Jurídica Indetificada
# y 3 tienen el tipo de actividad indentificada. Quizá sean las mismas.
# - Solo 1 no tiene indetificado el Sector temático 1
# - Solo 2 no tienen forma de localizarse físicamente al faltar:
#     * Codigo Tipo de Via,
#     * Tipo de via, Codigo de Calle,
#     * Nombre de la calle,
#     * Código de número de calle,
#     * Número de calle
#     * Latitud
#     * Longitud
#     * X_ETRS89
#     * Y_ETRS89

# %% [markdown]
# **Forma_Juridica**

# %%
df_entidades["Sector_Territorial"].value_counts()
# Out:
# barcelona             3963
# specific_districts      11
# Name: Sector_Territorial, dtype: int64

# %% [markdown]
# Entendiendo que donde es Nan es que es temporal, solo 3 entidades tienen actividad permanente, siendo el resto actividades temporales.

# %%
df_entidades["Forma_Juridica"].value_counts()
# Out:
# Associació                 4728
# Fundació                    383
# Altres                      178
# Cooperativa                 141
# Col·legis professionals      19
# Partit / Sindicat            17
# Gremis                       15
# Name: Forma_Juridica, dtype: int64

# %% [markdown]
# Vemos que tenemos tambien 3 entidades que cumplen ser "Grupo de hecho" y no "entidades", y probablemente son las mismas que tienen actividad permanente.
#
# Veamoslo:

# %% [markdown]
# Vemos que hay tres organizaciones con tipo de actividad "Pernamente" que no se cosndieran "Entidades" sino "Grupos de hecho", siendo el resto por omisión, Entidades temporales.
# Sería bueno verificar qué significa, es decir, si el resto se han creado ad-hoc para los proyectos o si trabajan por periodos, dado que se refiere a entidades y no a personas.

# %% [markdown]
# **Nom_Popular**

# %%
df_entidades_nom_popular = df_entidades.loc[df_entidades["Nom_Popular"].notna()]
df_entidades_nom_popular
# Out:
#      Tipologia_E_GF        Nif  Total_Voluntaris  Total_Professionals  \
# 2343              E  G63566467              40.0                  4.0
# 3610              E  G08943813               NaN                170.0
# 3720              E  G58071507              32.0                 61.0
# 5410              E  G85875409              11.0                  NaN
# 5433              E  F01909373               NaN                  NaN
# 5438              E  G44965960               NaN                  NaN
# 5443              E  G66712696               NaN                  NaN
# 5459              E  G59182766               NaN                  NaN
# 5460              E  G10972099               NaN                  NaN
# 5461              E  G65506917              35.0                  NaN
# 5474              E  G24815664              50.0                  5.0
#
#      Tipus_Activitat Forma_Juridica    Codi_E_GF  \
# 2343             NaN     Associació  99400172854
# ...

# %% [markdown]
# Encontramos 11 Entidades con nombre popular.

# %% [markdown]
# ## 2) Análisis de correlación entre entidades subveniconadas y no subvencionadas

# %% [markdown]
# ## 2) Análsis de entidades subvencionadas

# %% [markdown]
# Crecimiento anula de subvenciones

# %% [markdown]
# **Por tipus de Activitat**

# %% [markdown]
# Veamos si han sido subvencionadas:

# %%
df_entidades_actividad_permanente_subvencionadas=df_merged.loc[df_merged["Tipus_Activitat"] == "permanent"]
df_entidades_actividad_permanente_subvencionadas
# Out:
#       Tipologia_E_GF_x  Codi_E_GF Entitat_Municipal Organ_Gestor  Any  \
# 58557              NaN         89               NaN          NaN  NaN
# 58558              NaN         87               NaN          NaN  NaN
# 58559              NaN         86               NaN          NaN  NaN
#
#       Tipologia_De_Subvencio Objecte  Import_Sollicitat  \
# 58557                    NaN     NaN                NaN
# 58558                    NaN     NaN                NaN
# 58559                    NaN     NaN                NaN
#
#        Import_Total_Projecte  Import_Atorgat_Inicial  Import_Reintegrat_Total  \
# 58557                    NaN                     NaN                      NaN
# 58558                    NaN                     NaN                      NaN
# 58559                    NaN                     NaN                      NaN
#
#       Tipologia_E_GF_y  Nif  Total_Voluntaris  Total_Professionals  \
# 58557               GF  NaN               NaN                  NaN
# ...

# %% [markdown]
# No han sido subvencionadas.

# %% [markdown]
# **Por Nom popular**

# %%
df_entidades_nom_popular_subvencionadas=df_merged.loc[df_merged["Nom_Popular"].notna()]
df_entidades_nom_popular_subvencionadas
# Out:
#       Tipologia_E_GF_x    Codi_E_GF                     Entitat_Municipal  \
# 3922                 E  92086022186  Institut Municipal Barcelona Esports
# 3923                 E  92086022186  Institut Municipal Barcelona Esports
# 3924                 E  92086022186  Institut Municipal Barcelona Esports
# 3925                 E  92086022186  Institut Municipal Barcelona Esports
# 3926                 E  92086022186  Institut Municipal Barcelona Esports
# ...                ...          ...                                   ...
# 58530              NaN          265                                   NaN
# 58540              NaN          247                                   NaN
# 58541              NaN          246                                   NaN
# 58542              NaN          245                                   NaN
# 58552              NaN          227                                   NaN
#
#       Organ_Gestor     Any                      Tipologia_De_Subvencio  \
# ...

# %%
suma_importes = df_entidades_nom_popular_subvencionadas["Import_Atorgat_Inicial"].sum()
print(f"La suma de la columna Import_Atorgat_Inicial es: {suma_importes}")
# Out:
# La suma de la columna Import_Atorgat_Inicial es: 1481039.23

# %% [markdown]
# Presentació del conjunt de dades escollit: explicació i observacions generals del conjunt de dades a utilitzar per a fer el projecte final.
# Característiques generals: sense necessitat d'entrar molt en detall, explicar les principals característiques que defineixen aquest conjunt de dades. Tipologia, sector, tipus de dades, font, context, etc.
# Definició de les variables: explicació teòrica de les principals variables que conté el conjunt de dades.
# Presentació dels objectius: detallar els objectius inicials marcats de cara a extreure informació rellevant del conjunt de dades.
